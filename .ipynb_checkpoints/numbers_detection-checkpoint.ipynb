# %%
# !python -m pip install -U pip
# !pip install numpy
# !pip install matplotlib
# !pip install tensorflow
# !pip install pydot
# Out:
# Requirement already satisfied: pip in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (23.0.1)
# Requirement already satisfied: numpy in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tensorflow in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (2.12.0rc1)
# Requirement already satisfied: tensorflow-intel==2.12.0-rc1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.12.0rc1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.5)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (15.0.6.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (4.22.1)
# Requirement already satisfied: setuptools in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.51.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0rc0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0rc0)
# Requirement already satisfied: keras<2.13,>=2.12.0rc0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0rc1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0-rc1->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0-rc1->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.2.2)
# Requirement already satisfied: pydot in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\namst\appdata\local\programs\python\python311\lib\site-packages (from pydot) (3.0.9)

# %%
import keras

import numpy as np
friom 
import matplotlib.pyplot as plt

from keras import Sequential
from keras.layers import Dense, Input
from keras.datasets import mnist
from keras.optimizers import Adam
from keras.utils import plot_model
from keras.callbacks import LambdaCallback, ModelCheckpoint

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10345517474361816205
# xla_global_id: -1
# ]

# %%
# GET DATASETS

def get_numbers_data() -> tuple[tuple[np.ndarray, np.ndarray], tuple[np.ndarray, np.ndarray]]:
    return mnist.load_data()

(train_dataset, train_dataset_marks), (test_dataset, test_dataset_marks) = get_numbers_data()

print(f'{len(train_dataset)=}')
print(f'{len(train_dataset_marks)=}')
print(f'{len(test_dataset)=}')
print(f'{len(test_dataset_marks)=}')
# Out:
# len(train_dataset)=60000
# len(train_dataset_marks)=60000
# len(test_dataset)=10000
# len(test_dataset_marks)=10000

# %%
# SHOW EXAMPLES

def show_example_data(train_data: list[np.ndarray], columns: int = 4, rows: int = 5) -> None:
    figure = plt.figure(
        # figsize=(8, 8)
    )
    
    for i, img in enumerate(train_data[:4*5], start=1):
        # print(f"shape of {i} image => {img.shape[1:]}")
        figure.add_subplot(rows, columns, i)
        plt.imshow(img)
        
show_example_data(train_dataset)

# %%
# PREPARE DATASET

def prepare_data(raw_data: np.ndarray[np.ndarray]) -> np.ndarray[np.ndarray]:
    ret = raw_data.astype("float32") / 255
    ret = ret.reshape(-1, 28*28)
    # for i, img in enumerate(raw_data):
    #     img = img.astype(np.float32) / 255.0
    #     img = img.reshape((img.shape[0]*img.shape[1], )) # (784, ) shape
    #     ret[i] = img
        
    return ret
    
    
train_prepared_dataset = prepare_data(train_dataset)
test_prepared_dataset = prepare_data(test_dataset)
train_prepared_dataset_marks = keras.utils.to_categorical(train_dataset_marks, 10)
test_prepared_dataset_marks = keras.utils.to_categorical(test_dataset_marks, 10)
input_shape: tuple[int] = prepared_dataset[0].shape

print(f'{len(train_prepared_dataset)=}, {len(test_prepared_dataset)=}')
print(f'img with number => {train_dataset_marks[0]} with size {prepared_dataset[0].size} and {prepared_dataset[0].shape} linear shape')
print(f'{input_shape=}')
# Out:
# len(train_prepared_dataset)=60000, len(test_prepared_dataset)=10000
# img with number => 5 with size 784 and (784,) linear shape
# input_shape=(784,)

# %%
# MODEL

model = Sequential([
    Input(shape=input_shape),
    Dense(800, activation='relu'),
    Dense(200, activation='relu'),
    Dense(10, activation='softmax')
])

print(f'model successfully created => {model}')

# Ошибка:sparse_categorical_crossentropy 
# оптимизатор:adam
# метрика:accuracy

model.summary()
model.compile(loss='categorical_crossentropy', optimizer=Adam(0.001), metrics=['accuracy'])
plot_model(model, dpi=120)
# Out:
# model successfully created => <keras.engine.sequential.Sequential object at 0x0000023595236510>
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 800)               628000
#
#  dense_19 (Dense)            (None, 200)               160200
#
#  dense_20 (Dense)            (None, 10)                2010
#
# =================================================================
# Total params: 790,210
# Trainable params: 790,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
# PREPARE TRAIN

BATCH_SIZE: int = 64
EPOCHS: int = 15

# model.fit(prepared_dataset, )
# print(len(train_dataset_marks))
print(train_prepared_dataset[0].shape)
# Out:
# (784,)

# %%
# TRAIN

model.fit(train_prepared_dataset, train_prepared_dataset_marks, BATCH_SIZE, EPOCHS, validation_split=0.1)
# Out:
# Epoch 1/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0610 - val_accuracy: 0.9847
# Epoch 2/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0793 - val_accuracy: 0.9803
# Epoch 3/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.1011 - val_accuracy: 0.9792
# Epoch 4/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0878 - val_accuracy: 0.9828
# Epoch 5/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0773 - val_accuracy: 0.9828
# Epoch 6/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.1188 - val_accuracy: 0.9767
# Epoch 7/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.0892 - val_accuracy: 0.9848
# Epoch 8/15
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0894 - val_accuracy: 0.9823
# Epoch 9/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.1245 - val_accuracy: 0.9813
# Epoch 10/15
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.1175 - val_accuracy: 0.9815
# Epoch 11/15
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.1000 - val_accuracy: 0.9830
# Epoch 12/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.1150 - val_accuracy: 0.9830
# Epoch 13/15
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.1124 - val_accuracy: 0.9838
# Epoch 14/15
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.1054 - val_accuracy: 0.9853
# Epoch 15/15
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.1074 - val_accuracy: 0.9858

# %%
def test(test_index: int) -> None:
    
    img_arr = test_prepared_dataset[test_index]
    value = test_prepared_dataset_marks[test_index]

    correct_ans = np.argmax(value)
    img_expanded = np.expand_dims(img_arr, axis=0)
    plt.imshow(img_arr.reshape(28, 28))
    result = model.predict(img_expanded)
    # print('result => ' + str(result))
    predicted_number = np.argmax(result[0])
    # if correct_ans != predicted_number:
    
    print(f"LOOKS LIKE THIS IS \"{predicted_number}\" NUMBER WITH \"{result[0][predicted_number] * 100:.2f}\"%")
    print(f'IS ANSWER CORRECTNES => {correct_ans == predicted_number}, index => {i}')

# %%
# for i in range(20):
#     test(i)

test(30) # wrong
# Out:
# 1/1 [==============================] - 0s 14ms/step
# LOOKS LIKE THIS IS "3" NUMBER WITH "100.00"%
# IS ANSWER CORRECTNES => True, index => 19
